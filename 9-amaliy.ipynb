# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cf874046-fc67-43dc-a5d8-af8a01c851bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf874046-fc67-43dc-a5d8-af8a01c851bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('22 (1).csv')

rows, cols = df.shape
print("Satrlar soni:", rows)
print("Ustunlar soni:", cols)

df_clean = df.dropna()

deleted_rows = rows - df_clean.shape[0]
print("O'chirilgan satrlar soni:", deleted_rows)

print("\nNaN qiymatsiz dataset:")
print(df_clean)

grouped = df_clean.groupby("species").size()

print("\nSpecies bo'yicha guruhlash natijasi:")
print(grouped)
# Out:
# Satrlar soni: 5333
# Ustunlar soni: 8
# O'chirilgan satrlar soni: 4950
#
# NaN qiymatsiz dataset:
#                             species  year     variable    units magnitude  \
# 60    Alfonsino & Long-finned Beryx  2018  Asset value  Dollars  Millions
# 63    Alfonsino & Long-finned Beryx  2019  Asset value  Dollars  Millions
# 64    Alfonsino & Long-finned Beryx  2019        Catch   Tonnes    Actual
# 65    Alfonsino & Long-finned Beryx  2019         TACC   Tonnes    Actual
# 142                     All species  2018  Asset value  Dollars  Millions
# ...                             ...   ...          ...      ...       ...
# 5286             Yellow-eyed Mullet  2019        Catch   Tonnes    Actual
# 5287             Yellow-eyed Mullet  2019         TACC   Tonnes    Actual
# 5330                 Yellowfin Tuna  2019  Asset value  Dollars  Millions
# 5331                 Yellowfin Tuna  2019        Catch   Tonnes    Actual
# ...
